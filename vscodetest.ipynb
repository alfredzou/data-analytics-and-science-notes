# %%
print(r.ok)
print("helo")

# %%
print("helo")
print("1,2,3"

# %%
print("helo")
print("1,2,3")

# %%
from math import pi

def circle_area(r):
    if r < 0:
        assert ValueError
    if type(r) != (int or float):
        assert TypeError
    return pi * (r ** 2)

# %%
circle_area(5)
